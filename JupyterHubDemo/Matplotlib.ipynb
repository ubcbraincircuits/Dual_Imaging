# %% [markdown]
# ### Interactive Plotting with Jupyter and Matplotlib

# %% [markdown]
# https://medium.com/codingthesmartway-com-blog/getting-started-with-jupyter-notebook-for-python-4e7082bd5d46

# %%
from matplotlib import pyplot as plt
import numpy as np
import math
# %matplotlib notebook

# %% [markdown]
# ## Plotting trigonometric funtions

# %%
x = np.arange(0, 2*math.pi, 0.01)
sine = np.sin(x)
cosine = np.cos(x)
plt.plot(x,sine, label='Sine')
plt.plot(x,z, label='Cosine')
plt.ylabel('y')
plt.xlabel('x')
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %% [markdown]
# ## A Pie Chart

# %%
bars = ['Mahoneys', 'Gallery', 'Koerners', 'Porch']
ratings = [200,100,88,10]
plt.pie(ratings, labels=bars)
plt.title('Pie chart of `Favourite Bar on Campus` polled from 398 respondents')
# Out:
# <img src="data:image/png;base64,..." width="432">
# Text(0.5, 1.0, 'Pie chart of `Favourite Bar on Campus` polled from 398 respondents')

# %% [markdown]
# ### A Bar Chart

# %%
pies = ['Apple', 'Cherry', 'Key Lime', 'Pumpkin']
ratings = [200,100,88,10]
plt.bar(x=pies, height=ratings)
plt.title('Bar chart of `Favourite Pies` polled from 398 respondents')
# Out:
# <img src="data:image/png;base64,..." width="432">
# Text(0.5, 1.0, 'Bar chart of `Favourite Pies` polled from 398 respondents')

# %% [markdown]
# ### Working with Images

# %%
images = ['images/brain2000.jpeg',
          'images/brain3000.jpeg',
          'images/brain4000.jpeg']

# %%
images = [plt.imread(image) for image in images]

# %%
plt.imshow(images[0])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig, (ax1, ax2, ax3)  = plt.subplots(1,3)
ax1.imshow(images[0])
ax2.imshow(images[1])
ax3.imshow(images[2])
plt.
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
a
# Out:
# (<Figure size 640x480 with 3 Axes>,
#  array([<matplotlib.axes._subplots.AxesSubplot object at 0x00000081D4A41320>,
# ...
#        dtype=object))
